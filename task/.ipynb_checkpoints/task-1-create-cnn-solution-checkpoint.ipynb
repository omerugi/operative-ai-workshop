# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
import requests
from io import BytesIO
from Validations import *
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Step 1: Load the CIFAR-10 Dataset
#
# The CIFAR-10 dataset is directly available in TensorFlow/Keras.<br>
# Your Task: print the train_images, train_labels, test_images, test_labels shapes.<br>
# Replace the none with the corresponding command.

# %% [markdown]
# <details>
#     <summary>Click for a hint</summary>
#     <p>You can print the shapes using "---.shape" command</p>
# </details>

# %%
# Load the dataset
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
class_names = ["Airplane", "Automobile", "Bird", "Cat", "Deer", 
               "Dog", "Frog", "Horse", "Ship", "Truck"]

# %%
# Extracting dimensions and shapes
train_shape = train_images.shape
num_train_images = train_shape[0]
train_image_height = train_shape[1]
train_image_width = train_shape[2]
train_channels = train_shape[3]

test_shape = test_images.shape
num_test_images = test_shape[0]
test_image_height = test_shape[1]
test_image_width = test_shape[2]
test_channels = test_shape[3]

num_classes = len(class_names)

validate_dataset_info(train_shape, num_train_images, train_image_height, train_image_width, train_channels, 
                      test_shape, num_test_images, test_image_height, test_image_width, test_channels, 
                      num_classes, train_images, test_images, train_labels,test_labels, class_names)
# Out:
# All dataset dimensions are as expected. Good job!
# Training images shape: (50000, 32, 32, 3) meaning that we have 50000 training images, each image is of shape 32x32, in 3 channels
# Training labels shape: (50000, 1)
# Test images shape: (10000, 32, 32, 3) meaning that we have 10000 test images, each image is of shape 32x32, in 3 channels
# Test labels shape: (10000, 1)
# Number of classes: 10 and they are: ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# %% [markdown]
# ## Step 2: Explore the Dataset
#
# Visualization: Display a few images from the dataset. </br>
# Here we display few plots each one shows us the date in diffrent way.

# %%
images_to_display, labels_to_display = find_unique_images(train_images, train_labels, class_names)

# Plot sample images
plot_sample_images(images_to_display, labels_to_display, class_names)

# Plot class distribution
plot_class_distribution(train_labels, class_names)

# Plot high-dimensional data by reducing it to two dimensions
plot_tsne(train_images, train_labels, class_names)
# Out:
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.007s...
# [t-SNE] Computed neighbors for 5000 samples in 1.099s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 10.130883
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 103.375549
# [t-SNE] KL divergence after 1000 iterations: 2.879644

# %% [markdown]
# ## Step 3: Preprocess the Data

# %% [markdown]
# ### 3.1
# Your Task: Change the images types from int8 to float32.</br>
# Replace the None with the correct function in parameter that it takes so that it will change the type.</br>
# You can do so by using the ".astype(---)" command which take a <b>string</b> of the desired type.

# %% [markdown]
# <details>
#     <summary>Click for a hint</summary>
#     <p>You need to use " = train_images.astype("type_to_convert")" </p>
# </details>

# %%
print(f"The traning type: {str(train_images.dtype)}, The testing type: {str(test_images.dtype)}.")
# Out:
# The traning type: uint8, The testing type: uint8.

# %%
train_images_32 = train_images.astype("float32")
test_images_32 = test_images.astype("float32")

# %%
print(validate_type(train_images_32,test_images_32))
# Out:
# Type changed succefully!

# %% [markdown]
# ### 3.2
# <b>Note:</b> Pixel values are usually range between 0-255, when 0 is black and 255 is white.</br>
# <img src="https://what-when-how.com/wp-content/uploads/2012/07/tmp26dc25_thumb2.png" width="300" hight="150"> </br>
# By normalizing, we decrease the gap of the pixels values and compress them.</br>
# This allows the model to work better since the whitest value is not as far from the darkest value. (instead 0-255 we will have 0-1). </br></br>
# Your Task: Normalize the data to be between 0-1.</br>
# Replace the None with the correct value that need to dived by.</br>

# %% [markdown]
# <details>
#     <summary>Click for a hint</summary>
#     <p>To normalize a value that is in the rage 0-1000 to 0-1 we need to divied by the max value in our range, that is 1000. </br>
#         Exmaple: min value - 0/1000 = 0, mid value - 500/1000 = 0.5, max value - 1000/1000 = 1. </p>
# </details>

# %%
# Normalize the image pixel values by dividing by 255
train_images_norm = train_images_32/255
test_images_norm =  test_images_32/255

# This will print the minimum and maximum values of the training set
print(validate_norm_rage(train_images_norm,test_images_norm))
print("Normalized training set min value:", train_images_norm.min())
print("Normalized training set max value:", test_images_norm.max())
# Out:
# Normalization succeeded
# Normalized training set min value: 0.0
# Normalized training set max value: 1.0

# %%
plot_tsne(train_images_norm, train_labels, class_names)
# Out:
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.004s...
# [t-SNE] Computed neighbors for 5000 samples in 1.203s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 10.123097
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 99.677948
# [t-SNE] KL divergence after 1000 iterations: 2.861180

# %% [markdown]
# ## Step 4: Build the Neural Network Model
# Your Task: Build the layers of the network.</br>
# Replace the None with the correct valusy.

# %% [markdown]
# <details>
#     <summary>Click for a hint</summary>
#     <p>In the input layer (first Conv2D) the input shape should be the (width,hight,channels) of a single img </br>
#         In the output layer (last Dense) should be the number of classes.</p>
# </details>

# %%
model = Sequential()

# First convolutional layer with MaxPooling
# model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(None, None, None)))
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))

# Second convolutional layer with MaxPooling
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))  # Dropout layer

# Third convolutional layer with MaxPooling
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))  # Dropout layer

# Flatten the output to feed into a DNN
model.add(Flatten())

# Dense layer with 64 units
model.add(Dense(64, activation='relu'))

# Output layer with 10 units (one per class) and softmax activation
# model.add(Dense(None, activation='softmax'))
model.add(Dense(10, activation='softmax'))

# Print the model summary to check the model architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout (Dropout)           (None, 6, 6, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 2, 2, 64)          0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 73418 (286.79 KB)
# Trainable params: 73418 (286.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Step 5: Compile the Model
# Compile the model with an optimizer, loss function, and metrics

# %%
adam_optimizer = Adam(learning_rate=0.0001)  # Example: Setting learning rate to 0.0001

model.compile(optimizer=adam_optimizer, 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# Print a message to confirm model compilation
print("Model compiled successfully.")
# Out:
# Model compiled successfully.

# %% [markdown]
# ## Step 6: Train the Model
# Your Task: Train the model. For traning the model we will use the ".fit()" function which takes the train images and their labels.</br>
# Replace the None with the correct values.

# %%
epochs = 70

# Train the model
# history = model.fit(None, None, epochs=epochs)
history = model.fit(train_images_norm, train_labels, batch_size=12, epochs=epochs, validation_data=(test_images_norm, test_labels))

# Print a message to indicate the end of training
print("Model training completed.")
# Out:
# Epoch 1/70
# 4167/4167 [==============================] - 26s 6ms/step - loss: 1.8545 - accuracy: 0.3079 - val_loss: 1.5828 - val_accuracy: 0.4271
# Epoch 2/70
# 4167/4167 [==============================] - 32s 8ms/step - loss: 1.5572 - accuracy: 0.4326 - val_loss: 1.4708 - val_accuracy: 0.4790
# Epoch 3/70
# 4167/4167 [==============================] - 28s 7ms/step - loss: 1.4470 - accuracy: 0.4785 - val_loss: 1.3585 - val_accuracy: 0.5220
# Epoch 4/70
# 4167/4167 [==============================] - 28s 7ms/step - loss: 1.3618 - accuracy: 0.5124 - val_loss: 1.2686 - val_accuracy: 0.5542
# Epoch 5/70
# 4167/4167 [==============================] - 28s 7ms/step - loss: 1.3060 - accuracy: 0.5355 - val_loss: 1.2245 - val_accuracy: 0.5750
# Epoch 6/70
# 4167/4167 [==============================] - 28s 7ms/step - loss: 1.2558 - accuracy: 0.5562 - val_loss: 1.1873 - val_accuracy: 0.5880
# Epoch 7/70
# 4167/4167 [==============================] - 28s 7ms/step - loss: 1.2152 - accuracy: 0.5703 - val_loss: 1.1315 - val_accuracy: 0.6074
# Epoch 8/70
# 4167/4167 [==============================] - 28s 7ms/step - loss: 1.1826 - accuracy: 0.5826 - val_loss: 1.1090 - val_accuracy: 0.6175
# Epoch 9/70
# 4167/4167 [==============================] - 28s 7ms/step - loss: 1.1521 - accuracy: 0.5950 - val_loss: 1.0684 - val_accuracy: 0.6325
# Epoch 10/70
# 4167/4167 [==============================] - 29s 7ms/step - loss: 1.1181 - accuracy: 0.6067 - val_loss: 1.0826 - val_accuracy: 0.6314
# Epoch 11/70
# 4167/4167 [==============================] - 29s 7ms/step - loss: 1.0927 - accuracy: 0.6163 - val_loss: 1.0162 - val_accuracy: 0.6473
# Epoch 12/70
# 4167/4167 [==============================] - 29s 7ms/step - loss: 1.0685 - accuracy: 0.6253 - val_loss: 1.0019 - val_accuracy: 0.6519
# Epoch 13/70
# 4167/4167 [==============================] - 28s 7ms/step - loss: 1.0482 - accuracy: 0.6319 - val_loss: 0.9779 - val_accuracy: 0.6649
# Epoch 14/70
# 4167/4167 [==============================] - 29s 7ms/step - loss: 1.0267 - accuracy: 0.6378 - val_loss: 0.9736 - val_accuracy: 0.6666
# Epoch 15/70
# 4167/4167 [==============================] - 28s 7ms/step - loss: 1.0037 - accuracy: 0.6482 - val_loss: 0.9403 - val_accuracy: 0.6761
# Epoch 16/70
# 4167/4167 [==============================] - 28s 7ms/step - loss: 0.9923 - accuracy: 0.6517 - val_loss: 0.9283 - val_accuracy: 0.6786
# Epoch 17/70
# 4167/4167 [==============================] - 29s 7ms/step - loss: 0.9670 - accuracy: 0.6623 - val_loss: 0.9154 - val_accuracy: 0.6835
# Epoch 18/70
# 4167/4167 [==============================] - 28s 7ms/step - loss: 0.9578 - accuracy: 0.6641 - val_loss: 0.9118 - val_accuracy: 0.6900
# Epoch 19/70
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.9461 - accuracy: 0.6689 - val_loss: 0.9008 - val_accuracy: 0.6920
# Epoch 20/70
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.9279 - accuracy: 0.6764 - val_loss: 0.8786 - val_accuracy: 0.6994
# Epoch 21/70
# 4167/4167 [==============================] - 36s 9ms/step - loss: 0.9191 - accuracy: 0.6762 - val_loss: 0.8637 - val_accuracy: 0.6994
# Epoch 22/70
# 4167/4167 [==============================] - 36s 9ms/step - loss: 0.9045 - accuracy: 0.6837 - val_loss: 0.8568 - val_accuracy: 0.7083
# Epoch 23/70
# 4167/4167 [==============================] - 37s 9ms/step - loss: 0.8918 - accuracy: 0.6892 - val_loss: 0.8412 - val_accuracy: 0.7133
# Epoch 24/70
# 4167/4167 [==============================] - 38s 9ms/step - loss: 0.8815 - accuracy: 0.6920 - val_loss: 0.8438 - val_accuracy: 0.7131
# Epoch 25/70
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.8706 - accuracy: 0.6966 - val_loss: 0.8480 - val_accuracy: 0.7084
# Epoch 26/70
# 4167/4167 [==============================] - 30s 7ms/step - loss: 0.8682 - accuracy: 0.6972 - val_loss: 0.8164 - val_accuracy: 0.7210
# Epoch 27/70
# 4167/4167 [==============================] - 31s 8ms/step - loss: 0.8545 - accuracy: 0.7042 - val_loss: 0.8038 - val_accuracy: 0.7239
# Epoch 28/70
# 4167/4167 [==============================] - 31s 7ms/step - loss: 0.8437 - accuracy: 0.7054 - val_loss: 0.8053 - val_accuracy: 0.7216
# Epoch 29/70
# 4167/4167 [==============================] - 31s 8ms/step - loss: 0.8338 - accuracy: 0.7097 - val_loss: 0.8057 - val_accuracy: 0.7230
# Epoch 30/70
# 4167/4167 [==============================] - 31s 8ms/step - loss: 0.8230 - accuracy: 0.7128 - val_loss: 0.7957 - val_accuracy: 0.7252
# Epoch 31/70
# 4167/4167 [==============================] - 31s 7ms/step - loss: 0.8217 - accuracy: 0.7120 - val_loss: 0.7905 - val_accuracy: 0.7295
# Epoch 32/70
# 4167/4167 [==============================] - 31s 7ms/step - loss: 0.8109 - accuracy: 0.7158 - val_loss: 0.7848 - val_accuracy: 0.7326
# Epoch 33/70
# 4167/4167 [==============================] - 31s 7ms/step - loss: 0.8011 - accuracy: 0.7195 - val_loss: 0.7790 - val_accuracy: 0.7333
# Epoch 34/70
# 4167/4167 [==============================] - 40s 10ms/step - loss: 0.7958 - accuracy: 0.7230 - val_loss: 0.7968 - val_accuracy: 0.7263
# Epoch 35/70
# 4167/4167 [==============================] - 29s 7ms/step - loss: 0.7888 - accuracy: 0.7243 - val_loss: 0.7732 - val_accuracy: 0.7337
# Epoch 36/70
# 4167/4167 [==============================] - 29s 7ms/step - loss: 0.7852 - accuracy: 0.7263 - val_loss: 0.7757 - val_accuracy: 0.7360
# Epoch 37/70
# 4167/4167 [==============================] - 31s 7ms/step - loss: 0.7749 - accuracy: 0.7287 - val_loss: 0.7812 - val_accuracy: 0.7356
# Epoch 38/70
# 4167/4167 [==============================] - 30s 7ms/step - loss: 0.7698 - accuracy: 0.7315 - val_loss: 0.7664 - val_accuracy: 0.7370
# Epoch 39/70
# 4167/4167 [==============================] - 30s 7ms/step - loss: 0.7658 - accuracy: 0.7306 - val_loss: 0.7568 - val_accuracy: 0.7418
# Epoch 40/70
# 4167/4167 [==============================] - 29s 7ms/step - loss: 0.7633 - accuracy: 0.7322 - val_loss: 0.7463 - val_accuracy: 0.7462
# Epoch 41/70
# 4167/4167 [==============================] - 29s 7ms/step - loss: 0.7486 - accuracy: 0.7379 - val_loss: 0.7457 - val_accuracy: 0.7419
# Epoch 42/70
# 4167/4167 [==============================] - 37s 9ms/step - loss: 0.7455 - accuracy: 0.7380 - val_loss: 0.7453 - val_accuracy: 0.7441
# Epoch 43/70
# 4167/4167 [==============================] - 32s 8ms/step - loss: 0.7445 - accuracy: 0.7392 - val_loss: 0.7387 - val_accuracy: 0.7479
# Epoch 44/70
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.7362 - accuracy: 0.7431 - val_loss: 0.7445 - val_accuracy: 0.7444
# Epoch 45/70
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.7309 - accuracy: 0.7442 - val_loss: 0.7326 - val_accuracy: 0.7481
# Epoch 46/70
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.7300 - accuracy: 0.7434 - val_loss: 0.7366 - val_accuracy: 0.7517
# Epoch 47/70
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.7221 - accuracy: 0.7451 - val_loss: 0.7347 - val_accuracy: 0.7454
# Epoch 48/70
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.7193 - accuracy: 0.7473 - val_loss: 0.7330 - val_accuracy: 0.7497
# Epoch 49/70
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.7157 - accuracy: 0.7489 - val_loss: 0.7742 - val_accuracy: 0.7337
# Epoch 50/70
# 4167/4167 [==============================] - 30s 7ms/step - loss: 0.7113 - accuracy: 0.7513 - val_loss: 0.7276 - val_accuracy: 0.7518
# Epoch 51/70
# 4167/4167 [==============================] - 31s 7ms/step - loss: 0.7071 - accuracy: 0.7532 - val_loss: 0.7100 - val_accuracy: 0.7583
# Epoch 52/70
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.6998 - accuracy: 0.7541 - val_loss: 0.7174 - val_accuracy: 0.7565
# Epoch 53/70
# 4167/4167 [==============================] - 35s 8ms/step - loss: 0.6964 - accuracy: 0.7553 - val_loss: 0.7146 - val_accuracy: 0.7538
# Epoch 54/70
# 4167/4167 [==============================] - 32s 8ms/step - loss: 0.6915 - accuracy: 0.7561 - val_loss: 0.7097 - val_accuracy: 0.7563
# Epoch 55/70
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.6882 - accuracy: 0.7581 - val_loss: 0.7068 - val_accuracy: 0.7576
# Epoch 56/70
# 4167/4167 [==============================] - 31s 8ms/step - loss: 0.6826 - accuracy: 0.7592 - val_loss: 0.7070 - val_accuracy: 0.7524
# Epoch 57/70
# 4167/4167 [==============================] - 35s 9ms/step - loss: 0.6812 - accuracy: 0.7602 - val_loss: 0.7032 - val_accuracy: 0.7565
# Epoch 58/70
# 4167/4167 [==============================] - 30s 7ms/step - loss: 0.6782 - accuracy: 0.7618 - val_loss: 0.7000 - val_accuracy: 0.7636
# Epoch 59/70
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.6742 - accuracy: 0.7608 - val_loss: 0.7012 - val_accuracy: 0.7614
# Epoch 60/70
# 4167/4167 [==============================] - 32s 8ms/step - loss: 0.6737 - accuracy: 0.7626 - val_loss: 0.6931 - val_accuracy: 0.7624
# Epoch 61/70
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.6642 - accuracy: 0.7648 - val_loss: 0.6958 - val_accuracy: 0.7643
# Epoch 62/70
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.6621 - accuracy: 0.7637 - val_loss: 0.6922 - val_accuracy: 0.7636
# Epoch 63/70
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.6600 - accuracy: 0.7667 - val_loss: 0.6807 - val_accuracy: 0.7669
# Epoch 64/70
# 4167/4167 [==============================] - 35s 8ms/step - loss: 0.6527 - accuracy: 0.7697 - val_loss: 0.6953 - val_accuracy: 0.7648
# Epoch 65/70
# 4167/4167 [==============================] - 31s 7ms/step - loss: 0.6531 - accuracy: 0.7689 - val_loss: 0.7011 - val_accuracy: 0.7600
# Epoch 66/70
# 4167/4167 [==============================] - 29s 7ms/step - loss: 0.6500 - accuracy: 0.7714 - val_loss: 0.6855 - val_accuracy: 0.7632
# Epoch 67/70
# 4167/4167 [==============================] - 30s 7ms/step - loss: 0.6471 - accuracy: 0.7704 - val_loss: 0.6866 - val_accuracy: 0.7667
# Epoch 68/70
# 4167/4167 [==============================] - 30s 7ms/step - loss: 0.6442 - accuracy: 0.7721 - val_loss: 0.6753 - val_accuracy: 0.7683
# Epoch 69/70
# 4167/4167 [==============================] - 30s 7ms/step - loss: 0.6412 - accuracy: 0.7741 - val_loss: 0.6901 - val_accuracy: 0.7626
# Epoch 70/70
# 4167/4167 [==============================] - 29s 7ms/step - loss: 0.6424 - accuracy: 0.7729 - val_loss: 0.6784 - val_accuracy: 0.7663
# Model training completed.

# %% [markdown]
# ## Step 7: Evaluate the Model
#
# Your Task: Evaluate the model on the test dataset. For testing the model we will use the ".evaluate()" function which takes the test images and test labels.</br>
# Replace the None with the correct values.

# %%
# test_loss, test_accuracy = model.evaluate(None, None)
_, test_accuracy = model.evaluate(test_images_norm, test_labels)

# Print the test dataset accuracy
print("Test accuracy:", test_accuracy)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6784 - accuracy: 0.7663
# Test accuracy: 0.7663000226020813

# %% [markdown]
# ## Improvment
# Try to play with the numbers of epochs to get a better "accuracy" results.

# %% [markdown]
# ## Step 8: Test it yourself!
#
# Your Task: Find an image of one classes and test the model</br>
# Replace the None with the correct values.

# %%
# URL of the image to predict
image_url = 'https://cdn.britannica.com/17/126517-004-020A33AA/semi-semitrailer-truck-tractor-highway.jpg'

# Load and preprocess the image
img_array = load_and_preprocess_image(image_url)
# Predict the image
predictions = model.predict(img_array)
predicted_class = class_names[np.argmax(predictions)]

# Display the image and prediction
plt.imshow(img_array[0])
plt.title(f"Predicted class: {predicted_class}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 99ms/step
