# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
import requests
from io import BytesIO
from Validations import *
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Step 1: Load the CIFAR-10 Dataset
#
# The CIFAR-10 dataset is directly available in TensorFlow/Keras.<br>
# Your Task: print the train_images, train_labels, test_images, test_labels shapes.<br>
# Replace the none with the corresponding command.

# %% [markdown]
# <details>
#     <summary>Click for a hint</summary>
#     <p>You can print the shapes using "---.shape" command</p>
# </details>

# %%
# Load the dataset
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
class_names = ["Airplane", "Automobile", "Bird", "Cat", "Deer", 
               "Dog", "Frog", "Horse", "Ship", "Truck"]

# %%
print(f"Training images shape: {None} meaning that we have {None[0]} traning images, each image is of shape {None[1]}x{None[2]}, in {None[3]} channels (R-G-B)")
print("Training labels shape:", None)
print(f"Test images shape: {None} meaning that we have {None[0]} test images, each image is of shape {None[1]}x{None[2]}, in {None[3]} channels (R-G-B)")
print("Test labels shape:", None)
print(f"Number of classes: {len(class_names)} and they are: {class_names}")
# Out:
# Training images shape: (50000, 32, 32, 3) meaning that we have 50000 traning images, each image is of shape 32x32, in 3 channels (R-G-B)
# Training labels shape: (50000, 1)
# Test images shape: (10000, 32, 32, 3) meaning that we have 10000 test images, each image is of shape 32x32, in 3 channels (R-G-B)
# Test labels shape: (10000, 1)
# Number of classes: 10 and they are: ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# %% [markdown]
# ## Step 2: Explore the Dataset
#
# Visualization: Display a few images from the dataset. </br>
# Here we display the first 5 images from the training set

# %%
def plot_sample_images(images, labels, class_names):
    plt.figure(figsize=(15, 2))
    for i, (image, label) in enumerate(zip(images, labels)):
        plt.subplot(1, 10, i+1)
        plt.imshow(image)
        plt.title(class_names[label])
        plt.xticks([])
        plt.yticks([])
    plt.show()

def plot_class_distribution(labels, class_names):
    sns.set_style('whitegrid')
    plt.figure(figsize=(10, 6))
    sns.countplot(x=labels.flatten(), order=np.arange(len(class_names)))
    plt.xticks(np.arange(len(class_names)), class_names)
    plt.title('Distribution of Classes in Dataset')
    plt.xlabel('Class')
    plt.ylabel('Count')
    plt.show()

def plot_tsne(data, labels, class_names, n_samples=3000, perplexity=40, n_iter=300):
    """
    Plot t-SNE visualization for the given data.

    Parameters:
    data (numpy.ndarray): The image data.
    labels (numpy.ndarray): The corresponding labels of the data.
    class_names (list): List of class names corresponding to label indices.
    n_samples (int): Number of samples to use for t-SNE (default: 3000).
    perplexity (int): t-SNE perplexity parameter (default: 40).
    n_iter (int): Number of iterations for t-SNE optimization (default: 300).
    """
    # Select a subset of data and labels
    indices = np.random.choice(range(len(data)), n_samples, replace=False)
    X_subset = data[indices].reshape(n_samples, -1)
    y_subset = labels[indices].flatten()

    # Apply t-SNE
    tsne = TSNE(n_components=2, verbose=1, perplexity=perplexity, n_iter=n_iter)
    X_tsne = tsne.fit_transform(X_subset)

    # Plot
    plt.figure(figsize=(12, 8))
    for i in range(len(class_names)):
        indices = y_subset == i
        plt.scatter(X_tsne[indices, 0], X_tsne[indices, 1], label=class_names[i], alpha=0.5)
    plt.legend()
    plt.title('t-SNE visualization')
    plt.xlabel('t-SNE feature 1')
    plt.ylabel('t-SNE feature 2')
    plt.show()

# Load CIFAR-10 dataset
(train_images, train_labels), _ = tf.keras.datasets.cifar10.load_data()
class_names = ["Airplane", "Automobile", "Bird", "Cat", "Deer", 
               "Dog", "Frog", "Horse", "Ship", "Truck"]

# Find unique images to display
unique_labels = set()
images_to_display = []
labels_to_display = []

for i in range(len(train_labels)):
    label = train_labels[i][0]
    if label not in unique_labels:
        unique_labels.add(label)
        images_to_display.append(train_images[i])
        labels_to_display.append(label)
    if len(unique_labels) == len(class_names):
        break

# Plot sample images
plot_sample_images(images_to_display, labels_to_display, class_names)

# Plot class distribution
plot_class_distribution(train_labels, class_names)

# %% [markdown]
# ## Step 3: Preprocess the Data

# %% [markdown]
# ### 3.1
# Your Task: Change the images types from int8 to float32.</br>
# Replace the None with the correct function that changes the type.</br>
# You can do so by using the .astype command which take a <b>string</b> of the desired type.

# %% [markdown]
# <details>
#     <summary>Click for a hint</summary>
#     <p>You need to use " = train_images.astype(---)" </p>
# </details>

# %%
train_images_32 = train_images.astype("float32")
test_images_32 = test_images.astype("float32")

# %%
print(validate_type(train_images_32,test_images_32))
# Out:
# Type changed succefully!

# %% [markdown]
# ### 3.2
# <b>Note:</b> Pixel values are usually range between 0-255, when 0 is black and 255 is white.</br>
# <img src="https://what-when-how.com/wp-content/uploads/2012/07/tmp26dc25_thumb2.png" width="300" hight="150"> </br>
# by normalizing, we decrease the gap of the pixels values and compress them. this allows the model to work better since the whitest value is not as far from the darkest value. (instead 0-255 we will have 0-1). </br></br>
# Your Task: Normalize the data to be between 0-1.</br>
# Replace the None with the correct value that need to dived by.</br>

# %% [markdown]
# <details>
#     <summary>Click for a hint</summary>
#     <p>To normalize a value that is in the rage 0-1000 to 0-1 we need to divied by the max value in our range, that is 1000. </br>
#         Exmaple: min value - 0/1000 = 0, mid value - 500/1000 = 0.5, max value - 1000/1000 = 1. </p>
# </details>

# %%
# Normalize the image pixel values by dividing by 255
# train_images_norm = train_images_32/None
# test_images_norm =  test_images_32/None
train_images_norm = train_images_32/255.0
test_images_norm =  test_images_32/255.0

# Check if the data is normalized correctly (optional)
# This will print the minimum and maximum values of the training set
print(validate_norm_rage(train_images_norm,test_images_norm))
print("Normalized training set min value:", train_images_norm.min())
print("Normalized training set max value:", test_images_norm.max())
# Out:
# Normalization succeeded
# Normalized training set min value: 0.0
# Normalized training set max value: 1.0

# %% [markdown]
# ## Step 4: Build the Neural Network Model
# Your Task: Build the layers of the network.</br>
# Replace the None with the correct valusy.

# %% [markdown]
# <details>
#     <summary>Click for a hint</summary>
#     <p>In the input layer (first Conv2D) the input shape should be the (width,hight,channels) of a single img </br>
#         In the output layer (last Dense) should be the number of classes.</p>
# </details>

# %%
model = Sequential()

# First convolutional layer with MaxPooling
# model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(None, None, None)))
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))

# Second convolutional layer with MaxPooling
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))  # Dropout layer

# Third convolutional layer with MaxPooling
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))  # Dropout layer

# Flatten the output to feed into a DNN
model.add(Flatten())

# Dense layer with 64 units
model.add(Dense(64, activation='relu'))

# Output layer with 10 units (one per class) and softmax activation
# model.add(Dense(None, activation='softmax'))
model.add(Dense(10, activation='softmax'))

# Print the model summary to check the model architecture
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 30, 30, 32)        896
#
#  max_pooling2d_17 (MaxPooli  (None, 15, 15, 32)        0
#  ng2D)
#
#  conv2d_21 (Conv2D)          (None, 13, 13, 64)        18496
#
#  max_pooling2d_18 (MaxPooli  (None, 6, 6, 64)          0
#  ng2D)
#
#  dropout (Dropout)           (None, 6, 6, 64)          0
#
#  conv2d_22 (Conv2D)          (None, 4, 4, 64)          36928
#
#  max_pooling2d_19 (MaxPooli  (None, 2, 2, 64)          0
#  ng2D)
#
#  dropout_1 (Dropout)         (None, 2, 2, 64)          0
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 64)                16448
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 73418 (286.79 KB)
# Trainable params: 73418 (286.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Step 5: Compile the Model
# Compile the model with an optimizer, loss function, and metrics

# %%
adam_optimizer = Adam(learning_rate=0.0001)  # Example: Setting learning rate to 0.0001

model.compile(optimizer=adam_optimizer, 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# Print a message to confirm model compilation
print("Model compiled successfully.")
# Out:
# Model compiled successfully.

# %% [markdown]
# ## Step 6: Train the Model
# Your Task: Train the model. For traning the model we will use the ".fit()" function which takes the train images and their labels.</br>
# Replace the None with the correct values.

# %%
epochs = 40

# Train the model
# history = model.fit(None, None, epochs=epochs)
history = model.fit(train_images_norm, train_labels, batch_size=12, epochs=epochs, validation_data=(test_images_norm, test_labels))

# Print a message to indicate the end of training
print("Model training completed.")
# Out:
# Epoch 1/40
# 4167/4167 [==============================] - 31s 8ms/step - loss: 0.9039 - accuracy: 0.6850 - val_loss: 0.8735 - val_accuracy: 0.6985
# Epoch 2/40
# 4167/4167 [==============================] - 31s 7ms/step - loss: 0.8940 - accuracy: 0.6866 - val_loss: 0.8956 - val_accuracy: 0.6898
# Epoch 3/40
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.8809 - accuracy: 0.6911 - val_loss: 0.8440 - val_accuracy: 0.7088
# Epoch 4/40
# 4167/4167 [==============================] - 32s 8ms/step - loss: 0.8663 - accuracy: 0.6969 - val_loss: 0.8221 - val_accuracy: 0.7148
# Epoch 5/40
# 4167/4167 [==============================] - 36s 9ms/step - loss: 0.8599 - accuracy: 0.6985 - val_loss: 0.8468 - val_accuracy: 0.7116
# Epoch 6/40
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.8499 - accuracy: 0.7019 - val_loss: 0.8219 - val_accuracy: 0.7138
# Epoch 7/40
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.8411 - accuracy: 0.7054 - val_loss: 0.8072 - val_accuracy: 0.7197
# Epoch 8/40
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.8314 - accuracy: 0.7100 - val_loss: 0.8075 - val_accuracy: 0.7209
# Epoch 9/40
# 4167/4167 [==============================] - 32s 8ms/step - loss: 0.8234 - accuracy: 0.7123 - val_loss: 0.8096 - val_accuracy: 0.7187
# Epoch 10/40
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.8121 - accuracy: 0.7150 - val_loss: 0.8025 - val_accuracy: 0.7229
# Epoch 11/40
# 4167/4167 [==============================] - 37s 9ms/step - loss: 0.8077 - accuracy: 0.7165 - val_loss: 0.7806 - val_accuracy: 0.7280
# Epoch 12/40
# 4167/4167 [==============================] - 36s 9ms/step - loss: 0.7971 - accuracy: 0.7208 - val_loss: 0.7839 - val_accuracy: 0.7313
# Epoch 13/40
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.7967 - accuracy: 0.7210 - val_loss: 0.7795 - val_accuracy: 0.7333
# Epoch 14/40
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.7858 - accuracy: 0.7263 - val_loss: 0.7655 - val_accuracy: 0.7324
# Epoch 15/40
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.7772 - accuracy: 0.7277 - val_loss: 0.7777 - val_accuracy: 0.7294
# Epoch 16/40
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.7726 - accuracy: 0.7291 - val_loss: 0.7622 - val_accuracy: 0.7363
# Epoch 17/40
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.7640 - accuracy: 0.7327 - val_loss: 0.7961 - val_accuracy: 0.7244
# Epoch 18/40
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.7616 - accuracy: 0.7336 - val_loss: 0.7559 - val_accuracy: 0.7380
# Epoch 19/40
# 4167/4167 [==============================] - 36s 9ms/step - loss: 0.7511 - accuracy: 0.7363 - val_loss: 0.7546 - val_accuracy: 0.7408
# Epoch 20/40
# 4167/4167 [==============================] - 35s 8ms/step - loss: 0.7505 - accuracy: 0.7386 - val_loss: 0.7427 - val_accuracy: 0.7465
# Epoch 21/40
# 4167/4167 [==============================] - 32s 8ms/step - loss: 0.7427 - accuracy: 0.7405 - val_loss: 0.7413 - val_accuracy: 0.7411
# Epoch 22/40
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.7367 - accuracy: 0.7413 - val_loss: 0.7368 - val_accuracy: 0.7448
# Epoch 23/40
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.7261 - accuracy: 0.7449 - val_loss: 0.7555 - val_accuracy: 0.7388
# Epoch 24/40
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.7286 - accuracy: 0.7450 - val_loss: 0.7407 - val_accuracy: 0.7441
# Epoch 25/40
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.7233 - accuracy: 0.7452 - val_loss: 0.7248 - val_accuracy: 0.7488
# Epoch 26/40
# 4167/4167 [==============================] - 32s 8ms/step - loss: 0.7174 - accuracy: 0.7483 - val_loss: 0.7212 - val_accuracy: 0.7509
# Epoch 27/40
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.7120 - accuracy: 0.7496 - val_loss: 0.7375 - val_accuracy: 0.7466
# Epoch 28/40
# 4167/4167 [==============================] - 35s 8ms/step - loss: 0.7096 - accuracy: 0.7487 - val_loss: 0.7238 - val_accuracy: 0.7527
# Epoch 29/40
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.7032 - accuracy: 0.7548 - val_loss: 0.7187 - val_accuracy: 0.7537
# Epoch 30/40
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.6974 - accuracy: 0.7543 - val_loss: 0.7224 - val_accuracy: 0.7552
# Epoch 31/40
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.6969 - accuracy: 0.7566 - val_loss: 0.7097 - val_accuracy: 0.7544
# Epoch 32/40
# 4167/4167 [==============================] - 37s 9ms/step - loss: 0.6943 - accuracy: 0.7564 - val_loss: 0.7206 - val_accuracy: 0.7512
# Epoch 33/40
# 4167/4167 [==============================] - 38s 9ms/step - loss: 0.6830 - accuracy: 0.7601 - val_loss: 0.7095 - val_accuracy: 0.7570
# Epoch 34/40
# 4167/4167 [==============================] - 44s 11ms/step - loss: 0.6832 - accuracy: 0.7614 - val_loss: 0.7024 - val_accuracy: 0.7593
# Epoch 35/40
# 4167/4167 [==============================] - 43s 10ms/step - loss: 0.6793 - accuracy: 0.7625 - val_loss: 0.7236 - val_accuracy: 0.7488
# Epoch 36/40
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.6795 - accuracy: 0.7604 - val_loss: 0.7020 - val_accuracy: 0.7591
# Epoch 37/40
# 4167/4167 [==============================] - 34s 8ms/step - loss: 0.6722 - accuracy: 0.7634 - val_loss: 0.6896 - val_accuracy: 0.7630
# Epoch 38/40
# 4167/4167 [==============================] - 33s 8ms/step - loss: 0.6677 - accuracy: 0.7645 - val_loss: 0.7002 - val_accuracy: 0.7580
# Epoch 39/40
# 4167/4167 [==============================] - 37s 9ms/step - loss: 0.6607 - accuracy: 0.7683 - val_loss: 0.7049 - val_accuracy: 0.7551
# Epoch 40/40
# 4167/4167 [==============================] - 52s 12ms/step - loss: 0.6606 - accuracy: 0.7675 - val_loss: 0.6867 - val_accuracy: 0.7642
# Model training completed.

# %% [markdown]
# ## Step 7: Evaluate the Model
#
# Your Task: Evaluate the model on the test dataset. For testing the model we will use the ".evaluate()" function which takes the test images and test labels.</br>
# Replace the None with the correct values.

# %%
# test_loss, test_accuracy = model.evaluate(None, None)
_, test_accuracy = model.evaluate(test_images_norm, test_labels)

# Print the test dataset accuracy
print("Test accuracy:", test_accuracy)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6867 - accuracy: 0.7642
# Test accuracy: 0.76419997215271

# %% [markdown]
# ## Improvment
# Try to play with the numbers of epochs to get a better "accuracy" results.

# %% [markdown]
# ## Step 8: Test it yourself!
#
# Your Task: Find an image of one classes and test the model</br>
# Replace the None with the correct values.

# %%
# URL of the image to predict
image_url = 'https://cdn.britannica.com/17/126517-004-020A33AA/semi-semitrailer-truck-tractor-highway.jpg'

# Load and preprocess the image
img_array = load_and_preprocess_image(image_url)
# Predict the image
predictions = model.predict(img_array)
predicted_class = class_names[np.argmax(predictions)]

# Display the image and prediction
plt.imshow(img_array[0])
plt.title(f"Predicted class: {predicted_class}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 26ms/step
